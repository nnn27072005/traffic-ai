# %%
# notebooks/01_eda_fisheye.ipynb

import sys
sys.path.insert(0, "/kaggle/working/traffic-ai")

import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
from collections import Counter
from src.data.dataset import FishEye8KDataset

DATA_ROOT = "/kaggle/input/datasets/flap1812/fisheye8k/Fisheye8K"

train_ds = FishEye8KDataset(DATA_ROOT, split="train")
val_ds   = FishEye8KDataset(DATA_ROOT, split="test")
